# %%
# %load_ext autoreload
# %autoreload 2

# %%
import chemschematicresolver as csr
result = csr.extract_image('rde_evaluation_set/c3gc40334c-s3.gif', debug=True)
# Out:
# WARNING:chemschematicresolver.extract:Confidence of label 1 deemed too low for extraction
# 1 1
# 286 9

# %%
result
# Out:
# [(['1b'], 'c1cccc(c1)CCCOC')]

# %%
import reactiondataextractor as rde
result = rde.extract_image('rde_evaluation_set/c3cy00506b-s1_hi-res.gif')
# Out:
# 2022-02-24 15:06:43,482 [INFO] extract: Extraction started...
# INFO:extract:Extraction started...
# 2022-02-24 15:06:43,488 [INFO] extract.io_: Reading file - filepath: /Mounts/rbg-storage1/users/yujieq/reactiondataextractor/rde_evaluation_set/c3cy00506b-s1_hi-res.gif
# INFO:extract.io_:Reading file - filepath: /Mounts/rbg-storage1/users/yujieq/reactiondataextractor/rde_evaluation_set/c3cy00506b-s1_hi-res.gif
# 2022-02-24 15:06:43,602 [INFO] extract.arrows: An arrow candidate was discarded - insufficient pixel majority
# INFO:extract.arrows:An arrow candidate was discarded - insufficient pixel majority
# 2022-02-24 15:06:43,616 [INFO] extract.arrows: An arrow candidate was discarded - insufficient pixel majority
# INFO:extract.arrows:An arrow candidate was discarded - insufficient pixel majority
# 2022-02-24 15:06:43,625 [INFO] extract.arrows: An arrow candidate was discarded - insufficient pixel majority
# ...
